# %%
# packages
import duckdb
import pandas as pd

# %%
con = duckdb.connect("../guardian_articles.duckdb")

# Preview some cleaned articles
con.execute("SELECT id, webtitle, clean_body FROM cleaned_articles LIMIT 5").fetchdf()
# Out:
#                                                   id  \
# 0  commentisfree/2026/feb/22/the-guardian-view-on...
# 1  australia-news/2026/feb/23/ai-chatbots-schools...
# 2  world/2026/feb/22/erik-prince-drone-company-uk...
# 3  sport/2026/feb/22/the-great-olympic-lie-untold...
# 4  uk-news/2026/feb/22/governments-response-to-ma...
#
#                                             webTitle  \
# 0  The Guardian view on the funding crisis at the...
# 1  In some schools, chatbots interrogate students...
# 2  Blackwater founder Erik Prince has joined the ...
# 3  The Great Olympic lie: untold story of Winter ...
# 4  Government’s response to Maccabi Tel Aviv fan ...
#
#                                           clean_body
# 0   “The National Gallery is doing a great job is...
# 1  Once upon a time, school students would submit...
# 2  After multiple sources previously told the Gua...
# 3  On the foothills of the mountains, by the bank...
# 4  The government’s response to West Midlands pol...

# %%
df_counts = con.execute("SELECT COUNT (DISTINCT ID) FROM cleaned_articles").fetchdf()
print(df_counts)
# Out:
#    count(DISTINCT ID)
# 0               24124

# %%
# load table
df = con.execute("SELECT * FROM cleaned_articles").fetchdf()

# compute missing counts and percentages
missing_summary = pd.DataFrame(
    {"missing_count": df.isna().sum(), "missing_pct": 100 * df.isna().mean()}
).sort_values(by="missing_pct", ascending=False)

print(missing_summary)
# Out:
#                     missing_count  missing_pct
# pillarName                    227     0.940972
# pillarId                      227     0.940972
# id                              0     0.000000
# isHosted                        0     0.000000
# pull_date                       0     0.000000
# search_term                     0     0.000000
# shortUrl                        0     0.000000
# headline                        0     0.000000
# body                            0     0.000000
# type                            0     0.000000
# apiUrl                          0     0.000000
# webUrl                          0     0.000000
# webTitle                        0     0.000000
# webPublicationDate              0     0.000000
# sectionName                     0     0.000000
# sectionId                       0     0.000000
# clean_body                      0     0.000000

# %%
# looking into missing vars "pillarName" and "pillarId"

# %%
# look at most common variables
top5 = (
    df.groupby(["pillarName", "pillarId", "sectionId", "sectionName"])
    .size()
    .reset_index(name="n")
    .sort_values("n", ascending=False)
    .head(5)
)

print(top5)
# Out:
#    pillarName        pillarId       sectionId     sectionName isHosted     n
# 44       News     pillar/news      technology      Technology    False  2783
# 52    Opinion  pillar/opinion   commentisfree         Opinion    False  2211
# 51       News     pillar/news           world      World news    False  2193
# 48       News     pillar/news         us-news         US news    False  1700
# 18       News     pillar/news  australia-news  Australia news    False  1630

# %%
# counts by type
counts = df["type"].value_counts()
shares = df["type"].value_counts(normalize=True)

summary = pd.concat([counts, shares], axis=1)
summary.columns = ["count", "share"]

print(summary)
# Out:
#              count     share
# type
# article      22095  0.915893
# liveblog      1903  0.078884
# interactive    122  0.005057
# audio            3  0.000124
# picture          1  0.000041

# %%
counts_pillarName = df["pillarName"].value_counts()
shares_pillarName = df["pillarName"].value_counts(normalize=True)

summary_pillarName = pd.concat([counts_pillarName, shares_pillarName], axis=1)
summary_pillarName.columns = ["count", "share"]

print(summary_pillarName)
# Out:
#             count     share
# pillarName
# News        14182  0.593464
# Arts         4796  0.200695
# Opinion      2211  0.092522
# Lifestyle    1375  0.057539
# Sport        1333  0.055781

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Calculate shares
shares = df["pillarName"].value_counts(normalize=True, dropna=True)

# Sort for horizontal bar chart
shares = shares.sort_values()

plt.figure()
ax = shares.plot(kind="barh")

plt.xlabel("Share")
plt.ylabel("Pillar Name")
plt.title("Distribution of Articles by Pillar")


# data labels
for i, v in enumerate(shares):
    ax.text(
        v * 0.98,
        i,
        f"{v:.0%}",
        va="center",
        ha="right",
        color="white",
    )

plt.tight_layout()
# fixing a axis labels and limits
ax.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xlim(0, 1)

plt.show()

# %%
# Calculate shares
shares = (
    df["sectionName"].value_counts(normalize=True, dropna=True).head(10).sort_values()
)
# Sort for horizontal bar chart
# shares = shares.sort_values().head(10)

plt.figure()
ax = shares.plot(kind="barh")

plt.xlabel("Share")
plt.ylabel("Section Name")
plt.title("Distribution of Articles by Section")


# data labels
for i, v in enumerate(shares):
    ax.text(
        v * 0.98,
        i,
        f"{v:.0%}",
        va="center",
        ha="right",
        color="white",
    )

plt.tight_layout()
# fixing a axis labels and limits
ax.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xlim(0, 0.5)

plt.show()

# %%
# Close connection
con.close()

# %%
# calc counts and frequencies

# %%
# plotting
